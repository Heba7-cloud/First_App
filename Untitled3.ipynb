# %% [markdown]
# <a href="https://colab.research.google.com/github/Heba7-cloud/First_App/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, this is Heba Alariqi coding a simple Python code!")
# Out:
# Hello, this is Heba Alariqi coding a simple Python code!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive"
# Out:
# "1st Lab's assignment."  'Colab Notebooks'

# %%
# !git clone https://github.com/jpjacobpadilla/Google-Colab-Selenium.git
# Out:
# Cloning into 'Google-Colab-Selenium'...
# remote: Enumerating objects: 237, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 237 (delta 22), reused 17 (delta 17), pack-reused 213 (from 1)
# Receiving objects: 100% (237/237), 2.28 MiB | 8.93 MiB/s, done.
# Resolving deltas: 100% (147/147), done.
